# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import re

pd.set_option('display.max_rows', None)

# %%
#!ls -1 #Jupyter Notebook
# !dir #VSCODE
# Out:
#  O volume na unidade C � Windows
#  O N�mero de S�rie do Volume � 0676-E265
#
#  Pasta de c:\Users\henri\OneDrive\Documents\FIAP\3exemplo_dados_vendas_eletrodomesticos
# Arquivo n�o encontrado

# %%
df_original = pd.read_csv('exemplo_dados_vendas_eletrodomesticos.csv')
df = df_original

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4581 entries, 0 to 4580
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cd_produto    4581 non-null   int64
#  1   qtde          4581 non-null   int64
#  2   nota          4581 non-null   int64
#  3   preco_liq     4581 non-null   float64
#  4   preco_ipi     4581 non-null   float64
#  5   preco_icms    4581 non-null   float64
#  6   p_ipi         4581 non-null   int64
#  7   p_icm         4581 non-null   int64
#  8   nm_produto    4581 non-null   object
#  9   cd_cliente    4581 non-null   float64
#  10  nm_cliente    4581 non-null   object
#  11  cidade        4581 non-null   object
#  12  uf            4581 non-null   object
#  13  cd_vendedor   4581 non-null   int64
#  14  nm_vendedor   4581 non-null   object
#  15  cd_familia    4581 non-null   int64
#  16  nm_familia    4581 non-null   object
#  17  cd_grupo      4581 non-null   int64
#  18  nm_grupo      4581 non-null   object
#  19  cd_marca      4581 non-null   int64
#  20  nm_marca      4581 non-null   object
#  21  data_pedido   4581 non-null   object
#  22  data_nota     4581 non-null   object
#  23  cd_operacao   4581 non-null   float64
#  24  nm_operacao   4581 non-null   object
#  25  cd_sub_grupo  4581 non-null   int64
#  26  nm_sub_grupo  4581 non-null   object
#  27  cd_linha      4581 non-null   int64
#  28  nm_linha      4581 non-null   object
#  29  valor         4581 non-null   float64
#  30  lucro         4581 non-null   float64
# dtypes: float64(7), int64(11), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# ### EDA

# %%
# Calculando o lucro bruto por venda
#df['lucro_por_venda'] = df['valor'] - (df['preco_liq'] + df['preco_ipi'] + df['preco_icms'])
#ERROR print(df[['lucro', 'lucro_por_venda']])

#df['nota'].value_counts().sum()

print(df['nm_operacao'].value_counts().sum())
print("produtos vendidos:", df[df['nm_operacao'] == 'VENDAS']['nota'].value_counts().sum())
itens_por_pedido = df.groupby('nota')['cd_produto'].count()
print("Número de vendas:", itens_por_pedido.value_counts().sum())
# Out:
# 4581
# produtos vendidos: 2433
# Número de vendas: 2911

# %%
aa = df['nm_operacao'].value_counts()
plt.figure(figsize=(12, 6))

plt.bar(aa.index, aa.values)
plt.xlabel("Nome da Operação")
plt.ylabel("Número de Operações")
plt.title('Número de Cada Operação')
plt.grid(alpha=1)
plt.xticks(rotation=45, ha="right")  # Rotaciona os rótulos em 45 graus e alinha à direita
plt.tight_layout()  # Ajusta o layout para evitar sobreposição

plt.show()
print(df['nm_operacao'].value_counts())
# Out:
# nm_operacao
# VENDAS                 2433
# SEM REFERENCIA         1373
# VD P/ OUTRO ESTADO      414
# BENEFICIAMENTO          245
# REMESSA P IND.           99
# VENDA DE RESIDOS          6
# RETORNO DE MERC.          5
# DEVOLUCAO P/COMERC.       3
# CANCELADA                 1
# VENDA DE ATIVO            1
# RETORNO DA MERC           1
# Name: count, dtype: int64

# %%
print(df['cd_operacao'].value_counts())
# Out:
# cd_operacao
# 5.102    2434
# 9.999    1373
# 6.102     414
# 5.901     245
# 5.924      99
# 5.949       6
# 5.903       5
# 5.202       3
# 0.000       1
# 5.913       1
# Name: count, dtype: int64

# %% [markdown]
# ### 'cd_operacao' e 'nm_operacao' representam a mesma coisa
#
# cada tipo de operação com base nos nomes das operações:
#
# VENDAS: Indica uma venda padrão, ou seja, um produto foi vendido ao cliente final dentro do mesmo estado. Essa operação é a mais comum e representa a maioria das transações.
#
#
# SEM REFERENCIA: Refere-se a uma operação sem uma classificação específica ou desconhecida. Pode envolver transações atípicas ou de natureza administrativa, onde não foi designada uma categoria exata.
#
#
# VD P/ OUTRO ESTADO: "Venda para Outro Estado". Esta operação ocorre quando a venda é realizada para um cliente em um estado diferente. Geralmente, transações entre estados podem ter implicações fiscais, como alíquotas de ICMS (Imposto sobre Circulação de Mercadorias e Serviços) diferenciadas.
#
#
# BENEFICIAMENTO: Refere-se a operações de beneficiamento, que envolvem o envio de mercadorias para serem melhoradas, processadas ou tratadas antes de serem vendidas ou devolvidas ao inventário.
#
#
# REMESSA P IND.: "Remessa para Industrialização". Significa que o produto é enviado a uma empresa de industrialização, para receber processamento adicional antes de ser vendido ou devolvido.
#
#
# VENDA DE RESÍDUOS: Indica a venda de resíduos ou sobras de materiais, provavelmente provenientes de processos de fabricação ou industrialização.
#
#
# RETORNO DE MERCADORIA: Refere-se a produtos que foram enviados para fora da empresa (por exemplo, para beneficiamento ou industrialização) e estão sendo devolvidos ao estoque.
#
#
# DEVOLUÇÃO PARA COMÉRCIO: Indica uma devolução feita pelo cliente final ou por um comerciante. Pode ocorrer por vários motivos, como defeito no produto ou insatisfação do cliente.
#
#
# CANCELADA: Representa uma operação de venda que foi cancelada. Isso significa que a transação foi anulada e não houve entrega do produto.
#
#
# VENDA DE ATIVO: Essa operação se refere à venda de um ativo da empresa (e não de um produto destinado a clientes). Pode incluir máquinas, equipamentos, móveis, ou outros itens que fazem parte do patrimônio.
#
#
# RETORNO DA MERCADORIA: Similar ao "RETORNO DE MERCADORIA", mas o nome sugere que se trata de uma devolução de produtos que retornam ao estoque após serem enviados a algum cliente ou para outro destino.

# %%
#Outlier de data 1907?
datas_ordenadas = df['data_pedido'].sort_values().unique()
print(datas_ordenadas)
df = df[df['data_pedido'] != '1907-01-11 00:00:00']
# Out:
# ['1907-01-11' '2006-12-14' '2006-12-18' '2006-12-21' '2006-12-27'
#  '2007-01-08' '2007-01-16' '2007-01-18' '2007-01-22' '2007-01-24'
#  '2007-01-29' '2007-01-30' '2007-02-06' '2007-02-08' '2007-02-15'
#  '2007-02-16' '2007-02-22' '2007-02-26' '2007-02-27' '2007-03-06'
#  '2007-03-08' '2007-03-12' '2007-03-14' '2007-03-15' '2007-03-16'
#  '2007-03-19' '2007-03-20' '2007-03-22' '2007-03-27' '2007-04-03'
#  '2007-04-04' '2007-04-10' '2007-04-16' '2007-04-18' '2007-04-19'
#  '2007-04-23' '2007-05-03' '2007-05-11' '2007-05-14' '2007-05-15'
#  '2007-05-16' '2007-05-17' '2007-05-21' '2007-05-24' '2007-05-29'
#  '2007-06-04' '2007-06-05' '2007-06-18' '2007-06-21' '2007-06-25'
#  '2007-06-26' '2007-06-29' '2007-07-03' '2007-07-04' '2007-07-05'
#  '2007-07-11' '2007-07-16' '2007-07-31' '2007-08-08' '2007-08-13'
#  '2007-08-16' '2007-08-20' '2007-08-21' '2007-08-23' '2007-08-27'
#  '2007-09-03' '2007-09-06' '2007-09-11' '2007-09-12' '2007-09-20'
#  '2007-09-24' '2007-09-27' '2007-10-01' '2007-10-04' '2007-10-05'
#  '2007-10-08' '2007-10-09' '2007-10-16' '2007-10-17' '2007-10-22'
#  '2007-11-01' '2007-11-05' '2007-11-12' '2007-11-19' '2007-11-22'
#  '2007-11-26' '2007-12-04' '2007-12-07' '2007-12-10' '2007-12-19'
#  '2008-01-07' '2008-01-11' '2008-01-16' '2008-01-17' '2008-01-21'
#  '2008-01-22' '2008-01-29' '2008-02-01' '2008-02-07' '2008-02-12'
#  '2008-02-14' '2008-02-18' '2008-02-19' '2008-02-20' '2008-02-25'
#  '2008-02-28' '2008-02-29' '2008-03-06' '2008-03-07' '2008-03-10'
#  '2008-03-11' '2008-03-17' '2008-03-18' '2008-03-24' '2008-03-26'
#  '2008-03-27' '2008-03-28' '2008-03-31' '2008-04-01' '2008-04-02'
#  '2008-04-07' '2008-04-08' '2008-04-09' '2008-04-10' '2008-04-11'
#  '2008-04-15' '2008-04-16' '2008-04-17' '2008-04-18' '2008-04-22'
#  '2008-04-24' '2008-04-30' '2008-05-05' '2008-05-06' '2008-05-07'
#  '2008-05-08' '2008-05-09' '2008-05-12' '2008-05-13' '2008-05-14'
#  '2008-05-15' '2008-05-16' '2008-05-19' '2008-05-20' '2008-05-21'
#  '2008-05-26' '2008-05-27' '2008-05-29' '2008-05-30' '2008-06-03'
#  '2008-06-04' '2008-06-05' '2008-06-06' '2008-06-09' '2008-06-10'
#  '2008-06-11' '2008-06-12' '2008-06-13' '2008-06-17' '2008-06-18'
#  '2008-06-19' '2008-06-20' '2008-06-23' '2008-06-25' '2008-06-26'
#  '2008-06-30' '2008-07-02' '2008-07-04' '2008-07-07' '2008-07-11'
#  '2008-07-15' '2008-07-18' '2008-07-21' '2008-07-22' '2008-07-24'
#  '2008-07-29' '2008-07-30' '2008-08-01' '2008-08-04' '2008-08-05'
#  '2008-08-08' '2008-08-11' '2008-08-12' '2008-08-14' '2008-08-18'
#  '2008-08-19' '2008-08-20' '2008-08-21' '2008-08-22' '2008-08-26'
#  '2008-08-27' '2008-08-28' '2008-09-02' '2008-09-03' '2008-09-04'
#  '2008-09-05' '2008-09-08' '2008-09-10' '2008-09-16' '2008-09-17'
#  '2008-09-18' '2008-09-23' '2008-09-26' '2008-09-29' '2008-09-30'
#  '2008-10-02' '2008-10-08' '2008-10-10' '2008-10-13' '2008-10-16'
#  '2008-10-20' '2008-10-21' '2008-10-22' '2008-10-27' '2008-10-30'
#  '2008-11-04' '2008-11-10' '2008-11-18' '2008-11-19' '2008-11-25'
#  '2008-11-26' '2008-12-02' '2008-12-03' '2008-12-05' '2008-12-08'
#  '2008-12-09' '2008-12-12' '2008-12-15' '2008-12-17' '2009-01-07'
#  '2009-01-12' '2009-01-13' '2009-01-15' '2009-01-20' '2009-01-21'
#  '2009-01-22' '2009-01-23' '2009-01-26' '2009-01-29' '2009-02-02'
#  '2009-02-03' '2009-02-04' '2009-02-05' '2009-02-06' '2009-02-09'
#  '2009-02-10' '2009-02-11' '2009-02-12' '2009-02-13' '2009-02-16'
#  '2009-02-17' '2009-02-18' '2009-02-19' '2009-02-20' '2009-02-26'
#  '2009-02-27' '2009-03-02' '2009-03-03' '2009-03-04' '2009-03-05'
#  '2009-03-06' '2009-03-09' '2009-03-10' '2009-03-11' '2009-03-12'
#  '2009-03-13' '2009-03-16' '2009-03-17' '2009-03-18' '2009-03-19'
#  '2009-03-20' '2009-03-23' '2009-03-24' '2009-03-25' '2009-03-26'
#  '2009-03-27' '2009-03-30' '2009-03-31' '2009-04-01' '2009-04-02'
#  '2009-04-06' '2009-04-07' '2009-04-08' '2009-04-09' '2009-04-13'
#  '2009-04-14' '2009-04-15' '2009-04-16' '2009-04-17' '2009-04-20'
#  '2009-04-22' '2009-04-23' '2009-04-24' '2009-04-27' '2009-04-28'
#  '2009-04-29' '2009-04-30' '2009-05-04' '2009-05-05' '2009-05-06'
#  '2009-05-08' '2009-05-11' '2009-05-12' '2009-05-14' '2009-05-15'
#  '2009-05-18' '2009-05-19' '2009-05-20' '2009-05-21' '2009-05-22'
#  '2009-05-25' '2009-05-27' '2009-05-28' '2009-05-29' '2009-06-01'
#  '2009-06-02' '2009-06-03' '2009-06-04' '2009-06-05' '2009-06-08'
#  '2009-06-09' '2009-06-10' '2009-06-15' '2009-06-16' '2009-06-17'
#  '2009-06-18' '2009-06-19' '2009-06-22' '2009-06-23' '2009-06-24'
#  '2009-06-26' '2009-06-29' '2009-06-30' '2009-07-01' '2009-07-02'
#  '2009-07-03' '2009-07-06' '2009-07-07' '2009-07-08' '2009-07-10'
#  '2009-07-13' '2009-07-14' '2009-07-16' '2009-07-17' '2009-07-20'
#  '2009-07-21' '2009-07-22' '2009-07-23' '2009-07-24' '2009-07-27'
#  '2009-07-28' '2009-07-29' '2009-07-30' '2009-07-31' '2009-08-03'
#  '2009-08-04' '2009-08-05' '2009-08-06' '2009-08-07' '2009-08-10'
#  '2009-08-11' '2009-08-12' '2009-08-13' '2009-08-14' '2009-08-17'
#  '2009-08-18' '2009-08-19' '2009-08-20' '2009-08-21' '2009-08-24'
#  '2009-08-25' '2009-08-26' '2009-08-27' '2009-08-28' '2009-08-31'
#  '2009-09-01' '2009-09-02' '2009-09-03' '2009-09-04' '2009-09-08'
#  '2009-09-09' '2009-09-10' '2009-09-11' '2009-09-14' '2009-09-15'
#  '2009-09-16' '2009-09-17' '2009-09-18' '2009-09-21' '2009-09-22'
#  '2009-09-23' '2009-09-24' '2009-09-25' '2009-09-28' '2009-09-29'
#  '2009-09-30' '2009-10-01' '2009-10-02' '2009-10-05' '2009-10-06'
#  '2009-10-07' '2009-10-08' '2009-10-09' '2009-10-13' '2009-10-14'
#  '2009-10-15' '2009-10-16' '2009-10-19' '2009-10-20' '2009-10-21'
#  '2009-10-22' '2009-10-23' '2009-10-26' '2009-10-27' '2009-10-28'
#  '2009-10-29' '2009-10-30' '2009-11-03' '2009-11-04' '2009-11-05'
#  '2009-11-06' '2009-11-09' '2009-11-10' '2009-11-11' '2009-11-12'
#  '2009-11-13' '2009-11-16' '2009-11-17' '2009-11-18' '2009-11-19'
#  '2009-11-23' '2009-11-24' '2009-11-25' '2009-11-26' '2009-11-27'
#  '2009-11-30' '2009-12-01' '2009-12-02' '2009-12-03' '2009-12-04'
#  '2009-12-07' '2009-12-08' '2009-12-09' '2009-12-10' '2009-12-11'
#  '2009-12-14' '2009-12-15' '2009-12-16' '2009-12-17' '2009-12-18'
#  '2010-01-04' '2010-01-05' '2010-01-06' '2010-01-07' '2010-01-08'
#  '2010-01-11' '2010-01-12' '2010-01-13' '2010-01-14' '2010-01-15'
#  '2010-01-18' '2010-01-19' '2010-01-20' '2010-01-21' '2010-01-22'
#  '2010-01-26' '2010-01-27' '2010-01-28' '2010-01-29' '2010-02-01'
#  '2010-02-02' '2010-02-03' '2010-02-04' '2010-02-05' '2010-02-08'
#  '2010-02-09' '2010-02-10' '2010-02-11' '2010-02-12' '2010-02-18'
#  '2010-02-19' '2010-02-22' '2010-02-23' '2010-02-24' '2010-02-25'
#  '2010-02-26' '2010-03-01' '2010-03-02' '2010-03-03' '2010-03-04'
#  '2010-03-05' '2010-03-08' '2010-03-09' '2010-03-10' '2010-03-11'
#  '2010-03-12' '2010-03-15' '2010-03-16' '2010-03-17' '2010-03-18'
#  '2010-03-19' '2010-03-22' '2010-03-23' '2010-03-24' '2010-03-25'
#  '2010-03-26' '2010-03-29' '2010-03-30' '2010-03-31' '2010-04-01'
#  '2010-04-05' '2010-04-06' '2010-04-07' '2010-04-08' '2010-04-09'
#  '2010-04-12' '2010-04-13' '2010-04-14' '2010-04-15' '2010-04-16'
#  '2010-04-19' '2010-04-20' '2010-04-22' '2010-04-23' '2010-04-26'
#  '2010-04-27' '2010-04-28' '2010-04-29' '2010-04-30' '2010-05-03'
#  '2010-05-04' '2010-05-05' '2010-05-06' '2010-05-07' '2010-05-10'
#  '2010-05-11' '2010-05-12' '2010-05-13' '2010-05-14' '2010-05-17'
#  '2010-05-18' '2010-05-19' '2010-05-20' '2010-05-21' '2010-05-24'
#  '2010-05-25' '2010-05-26' '2010-05-27' '2010-05-28' '2010-05-31'
#  '2010-06-01' '2010-06-02' '2010-06-04' '2010-06-07' '2010-06-08'
#  '2010-06-09' '2010-06-10' '2010-06-11' '2010-06-14' '2010-06-15'
#  '2010-06-16' '2010-06-17' '2010-06-18' '2010-06-21' '2010-06-22'
#  '2010-06-23' '2010-06-24' '2010-06-25' '2010-06-28' '2010-06-29'
#  '2010-06-30' '2010-07-01' '2010-07-02' '2010-07-05' '2010-07-06'
#  '2010-07-07' '2010-07-08' '2010-07-12' '2010-07-13' '2010-07-14'
#  '2010-07-15' '2010-07-16' '2010-07-19' '2010-07-20' '2010-07-21'
#  '2010-07-22' '2010-07-23' '2010-07-26' '2010-07-27' '2010-07-28'
#  '2010-07-29' '2010-07-30' '2010-07-31' '2010-08-02' '2010-08-03'
#  '2010-08-04' '2010-08-05' '2010-08-06' '2010-08-09' '2010-08-10'
#  '2010-08-11' '2010-08-12' '2010-08-13' '2010-08-16' '2010-08-17'
#  '2010-08-18' '2010-08-19' '2010-08-20' '2010-08-23' '2010-08-24'
#  '2010-08-25' '2010-08-26' '2010-08-27' '2010-08-30' '2010-08-31'
#  '2010-09-01' '2010-09-02' '2010-09-03' '2010-09-06' '2010-09-08'
#  '2010-09-09' '2010-09-10' '2010-09-13' '2010-09-14' '2010-09-15'
#  '2010-09-16' '2010-09-17' '2010-09-20' '2010-09-21' '2010-09-22'
#  '2010-09-23' '2010-09-24' '2010-09-27' '2010-09-28' '2010-09-29'
#  '2010-09-30' '2010-10-01' '2010-10-04' '2010-10-05' '2010-10-06'
#  '2010-10-07' '2010-10-08' '2010-10-13' '2010-10-14' '2010-10-15'
#  '2010-10-18' '2010-10-19' '2010-10-20' '2010-10-21' '2010-10-22'
#  '2010-10-25' '2010-10-26' '2010-10-27' '2010-10-28' '2010-10-29'
#  '2010-11-01' '2010-11-03' '2010-11-04' '2012-01-04']

# %%
#A coluna 'nota' é o código da compra, "nota fiscal"
#print(orders['order_id'].value_counts())
#print(orders['order_hour_of_day'].unique())
#print(df['nota'].value_counts())
#df[df['nm_familia'] == 'NETBOOK'].head()

# %% [markdown]
# ### Modificando o df para nos aprofundarmos na análise

# %%
# Função para adicionar coluna de mês e ano
def adicionar_mes_ano(df, coluna_data):
    # Verifica se a coluna de data está no formato datetime
    if not pd.api.types.is_datetime64_any_dtype(df[coluna_data]):
        df[coluna_data] = pd.to_datetime(df[coluna_data])  # Converte a coluna para o tipo datetime
    
    # Extrai o ano e o mês como uma nova coluna 'mes_ano'
    df['mes_ano'] = df[coluna_data].dt.to_period("M")
    return df

# Adicionar coluna de mês e ano
df = adicionar_mes_ano(df, 'data_pedido')

# %%
# Função para adicionar coluna de dia da semana
def adicionar_dia_da_semana(df, coluna_data):
    # Verifica se a coluna de data está no formato datetime
    if not pd.api.types.is_datetime64_any_dtype(df[coluna_data]):
        df[coluna_data] = pd.to_datetime(df[coluna_data])  # Converte a coluna para o tipo datetime
    
    # Cria a nova coluna 'dia_da_semana' com o nome do dia da semana
    df['dia_da_semana'] = df[coluna_data].dt.day_name()
    return df

# Adicionando a coluna de dia da semana
df = adicionar_dia_da_semana(df, 'data_pedido')

# %%
# Define uma lista de famílias de produtos
familias = ['IPAD', 'NETBOOK', 'SMARTFONE', 'MICRO-COMPUTADOR', 'NOTEBOOK', 'CELULAR', 'INTEGRADOS']

# Altera a coluna 'categoria_produto' para 'eletronicos' quando 'nm_familia' está na lista
df.loc[df['nm_familia'].isin(familias), 'categoria_produto'] = 'eletronicos'

# Altera a coluna 'categoria_produto' para 'linha branca' quando 'nm_familia' é 'LINHA BRANCA'
df.loc[df['nm_familia'] == 'LINHA BRANCA', 'categoria_produto'] = 'linha branca'

# Altera a coluna 'categoria_produto' para 'linha marrom' quando 'nm_familia' é 'TV' ou 'RADIOS'
df.loc[df['nm_familia'].isin(['TV', 'RADIOS']), 'categoria_produto'] = 'linha marrom'


df.loc[df['nm_familia'] == 'ELETRODOMESTICOS DE COZINHA', 'categoria_produto'] = 'eletrodomesticos'

df.loc[df['nm_familia'] == 'TELEFONE FIXO ANTIGO', 'categoria_produto'] = 'outros'

df.loc[df['nm_familia'] == 'APARELHOS DE AR', 'categoria_produto'] = 'aparelhos de ar'

# Imprime as colunas relevantes para verificar as alterações
print(df[['nm_familia', 'categoria_produto']].head(20))
print(df[['nm_familia', 'categoria_produto']].value_counts())
df['categoria_produto'].value_counts()
# Out:
#           nm_familia categoria_produto
# 0       LINHA BRANCA      linha branca
# 1   MICRO-COMPUTADOR       eletronicos
# 2       LINHA BRANCA      linha branca
# 3   MICRO-COMPUTADOR       eletronicos
# 4         INTEGRADOS       eletronicos
# 5            NETBOOK       eletronicos
# 6             RADIOS      linha marrom
# 7   MICRO-COMPUTADOR       eletronicos
# 8         INTEGRADOS       eletronicos
# 9          SMARTFONE       eletronicos
# 10      LINHA BRANCA      linha branca
# 11        INTEGRADOS       eletronicos
# 12           NETBOOK       eletronicos
# 13              IPAD       eletronicos
# 14           NETBOOK       eletronicos
# 15      LINHA BRANCA      linha branca
# 16           NETBOOK       eletronicos
# 17                TV      linha marrom
# 18           NETBOOK       eletronicos
# 19           NETBOOK       eletronicos
# nm_familia                   categoria_produto
# ELETRODOMESTICOS DE COZINHA  eletrodomesticos     791
# NETBOOK                      eletronicos          703
# IPAD                         eletronicos          484
# APARELHOS DE AR              aparelhos de ar      382
# LINHA BRANCA                 linha branca         306
# TV                           linha marrom         291
# SMARTFONE                    eletronicos          272
# MICRO-COMPUTADOR             eletronicos          247
# NOTEBOOK                     eletronicos          237
# INTEGRADOS                   eletronicos          234
# RADIOS                       linha marrom         219
# CELULAR                      eletronicos          217
# TELEFONE FIXO ANTIGO         outros               198
# Name: count, dtype: int64
# categoria_produto
# eletronicos         2394
# eletrodomesticos     791
# linha marrom         510
# aparelhos de ar      382
# linha branca         306
# outros               198
# Name: count, dtype: int64

# %%
# Adiciona coluna com a data da primeira compra para cada cliente
df['data_primeira_compra'] = df.groupby('cd_cliente')['data_pedido'].transform('min')

# Adiciona coluna com a data da última compra para cada cliente
df['data_ultima_compra'] = df.groupby('cd_cliente')['data_pedido'].transform('max')

# Calcula os dias desde a primeira compra
df['dias_desde_primeira_compra'] = (df['data_pedido'] - df['data_primeira_compra']).dt.days

# Calcula os dias desde a última compra
df['dias_desde_ultima_compra'] = (df['data_pedido'] - df['data_ultima_compra']).dt.days

# %% [markdown]
# ### Não Perca!

# %%
#transformar em comentario, isso "filtra" faz com que somente as vendas estejam no df
dfaa = df

#df.loc[(df['lucro'] > 0) & (df['nm_operacao'] == 'SEM REFERENCIA'), 'nm_operacao'] = 'VENDAS'
#df.loc[(df['lucro'] > 0) & (df['cd_operacao'] == 5.102), 'cd_operacao'] = 9.999

"""df['nm_operacao'] = df['nm_operacao'].replace('SEM REFERENCIA', 'VENDAS')
df['cd_operacao'] = df['cd_operacao'].replace('5.102', '9.999')"""
df = df[df['nm_operacao'] == 'VENDAS']

# %%
dfaa = dfaa[dfaa['data_pedido'] != '1907-01-11 00:00:00']

VENDAS = df
SEM_REFERENCIA = dfaa[dfaa['nm_operacao'] == 'SEM REFERENCIA']
# Calcula o lucro mensal para cada DataFrame
lucro_mensal = df.groupby('mes_ano')['lucro'].sum()
lucro_mensal.index = lucro_mensal.index.to_timestamp()

lucro_mensal_dfaa = dfaa.groupby('mes_ano')['lucro'].sum()
lucro_mensal_dfaa.index = lucro_mensal_dfaa.index.to_timestamp()

lucro_mensal_SEM_REFERENCIA = SEM_REFERENCIA.groupby('mes_ano')['lucro'].sum()
lucro_mensal_SEM_REFERENCIA.index = lucro_mensal_SEM_REFERENCIA.index.to_timestamp()

# Cria o gráfico com as duas linhas de lucro mensal
plt.figure(figsize=(12, 6))

# Ajuste de índices e valores de cada DataFrame
plt.plot(lucro_mensal_dfaa.index, lucro_mensal_dfaa.values, marker='o', linestyle='-', color='g', label="TODAS AS OPERAÇÕES")
plt.plot(lucro_mensal.index, lucro_mensal.values, marker='o', linestyle='-', color='b', label="VENDAS")
plt.plot(lucro_mensal_SEM_REFERENCIA.index, lucro_mensal_SEM_REFERENCIA.values, marker='o', linestyle='-', color='r', label="SEM REFERENCIA")

# Configurações dos eixos e título
plt.xlabel("Mês")
plt.ylabel("Lucro Total")
plt.title("Comparação do Lucro Mensal entre Operações")
plt.legend()  # Adiciona a legenda para distinguir as duas séries
plt.grid(alpha=0.3)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Agrupar por 'mes_ano' e calcular o total de vendas para cada mês
#vendas_mensais = df.groupby('mes_ano')['valor'].sum()
vendas_mensais = df.groupby('mes_ano')['nota'].count()

# Converter o índice para datetime para facilitar a plotagem
vendas_mensais.index = vendas_mensais.index.to_timestamp()

# Plotando o desempenho das vendas ao longo dos meses
plt.figure(figsize=(12, 6))
plt.plot(vendas_mensais.index, vendas_mensais.values, marker='o', linestyle='-', color='b')
plt.xlabel("Mês")
plt.ylabel("Total de Vendas")
plt.title("Desempenho Mensal das Vendas")
plt.grid(alpha=0.3)
plt.xticks(rotation=45)

plt.show()

# %%
dfaa['nm_produto'].value_counts()
# Out:
# nm_produto
# MOEDORA ARNO Serie 03                       645
# MEDIA LEMBRANCA MICROLIXO Serie 84          354
# VENTOSO VENTILVA Serie 35                   228
# MUITA LEMBRANCA GRAMPOLA Serie 85           162
# CELULAR TECLADO Motorola Serie 34           151
# ALGUMA LEMBRANCA ITAUTEC Serie 85           121
# PRETO DO BISAVO TELESP Serie 35             116
# ATE 50 LITROS PRADARIA Serie 78              90
# IMAGEM AVANCADA LG Serie 56                  81
# CELULAR COM MP3+MP3+MP3+TV Nokia Serie 8     73
# MEDIA LEMBRANCA SISNE Serie 85               72
# ATE 20 LITROS BRASTEMP Serie 35              71
# MEDIA LEMBRANCA VIVALDA Serie 85             67
# COM RELOGIO CONSORTE FUNCA Serie 85          64
# MUITA LEMBRANCA IMPERION Serie 78            61
# VAGA LEMBRANCA HP Serie 35                   54
# MOEDORA ARNO Serie 35                        53
# IMAGEM NORMAL MONTVELHO Serie 99             51
# MUITA LEMBRANCA CELL LIBERTY Serie 84        51
# ATE 50 LITROS PRADARIA Serie 92              44
# MEDIA LEMBRANCA DELL Serie 99                42
# ALGUMA LEMBRANCA BRAS-SUL Serie 99           41
# COM MP3 PLUGS Serie 85                       41
# UM POUCO DE TUDO PLUGS Serie 42              40
# MEDIA LEMBRANCA SISNE Serie 99               40
# MEDIA LEMBRANCA MICROLIXO Serie 78           37
# IMAGEM ULTRA VENDAVAL Serie 27               35
# MUITA LEMBRANCA DISMAC Serie 85              33
# +TOUCH+TV PING LING Serie 49                 32
# CELULAR COM MP3+MP3+MP3+TV CELL LING Ser     31
# MEDIA LEMBRANCA SISNE Serie 13               30
# COM MP3 BUSHA DE CANHAO Serie 85             30
# COM RELOGIO CLARION Serie 49                 30
# MUITA LEMBRANCA DELL Serie 78                29
# CONDICIONA AR VENTILVA Serie 49              28
# CELULAR COM MP3+MP3 CELL LING Serie 57       28
# ATE 50 LITROS BRASTEMP Serie 77              28
# UM POUCO DE TUDO BUSHA DE CANHAO Serie 9     27
# CONDICIONA AR CARRIER Serie 49               26
# CONDICIONA AR CISCO KID Serie 92             26
# MUITA LEMBRANCA BRAS-SUL Serie 27            24
# MEDIA LEMBRANCA MICROLIXO Serie 27           23
# ALGUMA LEMBRANCA HP Serie 99                 23
# ALGUMA LEMBRANCA MICROTEC Serie 99           22
# SEM LEMBRANCA GRAMPOLA Serie 99              22
# +TOUCH+TV Motorola Serie 49                  21
# COM RELOGIO BRASNORTH Serie 99               20
# MEDIA LEMBRANCA DISMAC Serie 99              20
# UM POUCO DE TUDO CONSORTE FUNCA Serie 99     19
# IMAGEM NORMAL VENDAVAL Serie 42              19
# MUITA LEMBRANCA MICROTEC Serie 84            19
# BONZINHO PRADA Serie 85                      16
# IMAGEM ULTRA VENDAVAL Serie 85               16
# MAIS OU MENOS CONSORTE FUNCA Serie 28        15
# TORRADORA ARNO Serie 85                      15
# MUITA LEMBRANCA BRAS-SUL Serie 85            15
# UM POUCO DE TUDO BUSHA DE CANHAO Serie 5     15
# MUITA LEMBRANCA ITAUTEC Serie 78             15
# MUITA LEMBRANCA HP Serie 78                  14
# ATE 50 LITROS BRASTEMP Serie 49              13
# IMAGEM NORMAL VENDAVAL Serie 83              12
# BONZINHO BUSHA DE CANHAO Serie 27            12
# CONDICIONA AR VENTILVA Serie 85              11
# ALGUMA LEMBRANCA ITAUTEC Serie 99            11
# TORRADORA LT Serie 92                        11
# ALGUMA LEMBRANCA ITAUTEC Serie 42            10
# CELULAR COM MP3 JPG Serie 34                 10
# IMAGEM AVANCADA MONTVELHO Serie 27            9
# CELULAR COM MP3 JPG Serie 42                  9
# CELULAR TECLADO+TOUCH Motorola Serie 20       8
# CELULAR TECLADO Motorola Serie 58             8
# TORRADORA ARNO Serie 77                       8
# TORRADORA ARNO Serie 49                       8
# MEDIA LEMBRANCA VIVALDA Serie 92              7
# UM POUCO DE TUDO CONSORTE FUNCA Serie 58      7
# ALGUMA LEMBRANCA IMPERION Serie 49            7
# MUITA LEMBRANCA DISMAC Serie 68               7
# CELULAR COM MP3+MP3 Nokia Serie 28            7
# PLASTICO MODERNO TELESP Serie 85              6
# IMAGEM AVANCADA LG Serie 42                   6
# IMAGEM ULTRA LG Serie 70                      6
# ATE 50 LITROS CONSUL Serie 49                 6
# MEDIA LEMBRANCA VIVALDA Serie 78              6
# BONZINHO PRADA Serie 99                       6
# UM POUCO DE TUDO BRASNORTH Serie 42           6
# CELULAR COM MP3+MP3 CELL LING Serie 99        6
# PLASTICO MODERNO TELESP Serie 49              6
# PLASTICO DA TELESP TELESP Serie 08            5
# MEDIA LEMBRANCA SISNE Serie 68                5
# IMAGEM ULTRA MONTVELHO Serie 78               5
# SEM LEMBRANCA ITAUTEC Serie 99                5
# ATE 20 LITROS BRASTEMP Serie 63               5
# BONZINHO PRADA Serie 56                       5
# CONDICIONA AR CARRIER Serie 92                5
# MUITA LEMBRANCA IMPERION Serie 92             5
# CONDICIONA AR CISCO KID Serie 77              5
# COM MP3 PLUGS Serie 28                        5
# PRETO DO BISAVO TELESP Serie 58               5
# ALGUMA LEMBRANCA HP Serie 63                  5
# VAGA LEMBRANCA CELL LIBERTY Serie 99          4
# PLASTICO DA TELESP TELESP Serie 28            4
# PLASTICO MODERNO VELHUSCO Serie 49            4
# TORRADORA BOSCH Serie 79                      4
# CELULAR TECLADO+TOUCH Motorola Serie 28       4
# BONZINHO PRADA Serie 42                       4
# MEDIA LEMBRANCA MICROLIXO Serie 09            4
# MUITA LEMBRANCA CELL LIBERTY Serie 92         4
# CELULAR TECLADO+TOUCH PING LING Serie 00      4
# SEM LEMBRANCA ITAUTEC Serie 35                4
# MUITA LEMBRANCA CELL LIBERTY Serie 70         4
# VAGA LEMBRANCA VIVALDA Serie 99               4
# MUITA LEMBRANCA ITAUTEC Serie 70              4
# MUITA LEMBRANCA HP Serie 49                   4
# CELULAR COM MP3 Nokia Serie 99                4
# IMAGEM AVANCADA LG Serie 85                   4
# MAIS OU MENOS CLARION Serie 99                4
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 99       3
# RERIGERA CISCO KID Serie 63                   3
# CONDICIONA AR CARRIER Serie 79                3
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 92       3
# IMAGEM AVANCADA MONTVELHO Serie 49            3
# MEDIA LEMBRANCA MICROLIXO Serie 70            3
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 28       3
# TORRADORA BOSCH Serie 49                      3
# PLASTICO MODERNO VELHUSCO Serie 06            3
# BONZINHO PRADA Serie 80                       3
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 49       3
# PLASTICO MODERNO LIXXOR Serie 42              3
# BATE LT Serie 63                              3
# PRETO DO BISAVO LIXXOR Serie 42               3
# MEDIA LEMBRANCA MICROLIXO Serie 99            3
# RERIGERA VENTILVA Serie 20                    3
# PRETO DO BISAVO LIXXOR Serie 57               3
# BATE BOSCH Serie 59                           3
# PLASTICO DA TELESP VELHUSCO Serie 49          2
# MEDIA LEMBRANCA MICROLIXO Serie 06            2
# CELULAR COM MP3 Nokia Serie 03                2
# ALGUMA LEMBRANCA HP Serie 45                  2
# CELULAR TECLADO Motorola Serie 03             2
# ATE 30 LITROS PRADARIA Serie 63               2
# ATE 20 LITROS CONSUL Serie 02                 2
# SEM LEMBRANCA ITAUTEC Serie 55                2
# IMAGEM AVANCADA LG Serie 63                   2
# VENTOSO VENTILVA Serie 97                     2
# COM RELOGIO BRASNORTH Serie 81                2
# ALGUMA LEMBRANCA ITAUTEC Serie 51             2
# MEDIA LEMBRANCA MICROLIXO Serie 86            2
# MEDIA LEMBRANCA CELL LIBERTY Serie 20         2
# VAGA LEMBRANCA MICROLIXO Serie 35             2
# ATE 20 LITROS CONSUL Serie 00                 2
# CONDICIONA AR CISCO KID Serie 99              2
# ATE 50 LITROS PRADARIA Serie 84               2
# MEDIA LEMBRANCA CELL LIBERTY Serie 49         2
# ALGUMA LEMBRANCA HP Serie 40                  2
# MUITA LEMBRANCA DELL Serie 71                 2
# CELULAR COM MP3 CELL LING Serie 99            2
# CELULAR TECLADO+TOUCH PING LING Serie 57      2
# ATE 50 LITROS PRADARIA Serie 87               2
# COM MP3 PLUGS Serie 16                        2
# MUITA LEMBRANCA DISMAC Serie 12               2
# MEDIA LEMBRANCA CELL LIBERTY Serie 42         2
# CELULAR COM MP3 CELL LING Serie 94            2
# CELULAR COM MP3+MP3 CELL LING Serie 85        2
# MAIS OU MENOS BRASNORTH Serie 04              2
# +TOUCH+TV DELETOU Serie 92                    2
# CELULAR COM MP3 Nokia Serie 58                2
# MUITA LEMBRANCA CELL LIBERTY Serie 87         2
# CELULAR TECLADO+TOUCH PING LING Serie 41      2
# IMAGEM ULTRA VENDAVAL Serie 68                2
# CONDICIONA AR CARRIER Serie 09                2
# MUITA LEMBRANCA BRAS-SUL Serie 68             2
# MEDIA LEMBRANCA MICROLIXO Serie 98            2
# MUITA LEMBRANCA MICROTEC Serie 49             2
# MAIS OU MENOS CLARION Serie 80                2
# COM MP3 BUSHA DE CANHAO Serie 13              2
# IMAGEM AVANCADA VENDAVAL Serie 99             2
# MUITA LEMBRANCA MICROTEC Serie 67             2
# MUITA LEMBRANCA DISMAC Serie 69               2
# COM RELOGIO BRASNORTH Serie 28                2
# ATE 30 LITROS BRASTEMP Serie 21               2
# CELULAR TECLADO Motorola Serie 99             2
# MAIS OU MENOS CLARION Serie 42                2
# UM POUCO DE TUDO CLARION Serie 58             2
# TORRADORA LT Serie 77                         2
# CELULAR COM MP3 CELL LING Serie 41            2
# MEDIA LEMBRANCA DELL Serie 58                 2
# CELULAR COM MP3 Nokia Serie 73                2
# CONDICIONA AR CISCO KID Serie 82              2
# TORRADORA BOSCH Serie 92                      2
# PLASTICO MODERNO VELHUSCO Serie 92            2
# ALGUMA LEMBRANCA MICROTEC Serie 40            2
# MOEDORA LT Serie 42                           2
# VENTOSO CISCO KID Serie 42                    2
# MUITA LEMBRANCA GRAMPOLA Serie 78             2
# MUITA LEMBRANCA BRAS-SUL Serie 52             2
# ALGUMA LEMBRANCA MICROTEC Serie 48            2
# COM MP3 PLUGS Serie 13                        2
# ATE 20 LITROS PRADARIA Serie 42               2
# ATE 50 LITROS PRADARIA Serie 14               1
# ATE 50 LITROS BRASTEMP Serie 11               1
# MEDIA LEMBRANCA MICROLIXO Serie 64            1
# IMAGEM ULTRA LG Serie 68                      1
# PRETO DO BISAVO VELHUSCO Serie 75             1
# MUITA LEMBRANCA IMPERION Serie 47             1
# MUITA LEMBRANCA CELL LIBERTY Serie 67         1
# ALGUMA LEMBRANCA ITAUTEC Serie 81             1
# IMAGEM AVANCADA LG Serie 04                   1
# UM POUCO DE TUDO CLARION Serie 02             1
# VAGA LEMBRANCA VIVALDA Serie 94               1
# MEDIA LEMBRANCA VIVALDA Serie 10              1
# MUITA LEMBRANCA DELL Serie 92                 1
# COM RELOGIO BRASNORTH Serie 18                1
# MEDIA LEMBRANCA VIVALDA Serie 83              1
# COM MP3 PRADA Serie 93                        1
# MAIS OU MENOS CONSORTE FUNCA Serie 81         1
# ALGUMA LEMBRANCA BRAS-SUL Serie 60            1
# ALGUMA LEMBRANCA ITAUTEC Serie 26             1
# COM RELOGIO CLARION Serie 11                  1
# VENTOSO CISCO KID Serie 76                    1
# VAGA LEMBRANCA SISNE Serie 63                 1
# CONDICIONA AR CISCO KID Serie 53              1
# CONDICIONA AR CISCO KID Serie 45              1
# VENTOSO CISCO KID Serie 84                    1
# VAGA LEMBRANCA VIVALDA Serie 82               1
# COM RELOGIO BRASNORTH Serie 01                1
# TORRADORA LT Serie 53                         1
# +TOUCH+TV DELETOU Serie 01                    1
# COM MP3 PRADA Serie 29                        1
# CONDICIONA AR CISCO KID Serie 62              1
# BATE ARNO Serie 84                            1
# COM RELOGIO BRASNORTH Serie 76                1
# ATE 20 LITROS BRASTEMP Serie 66               1
# MUITA LEMBRANCA BRAS-SUL Serie 92             1
# CELULAR TECLADO+TOUCH PING LING Serie 51      1
# MUITA LEMBRANCA BRAS-SUL Serie 71             1
# MUITA LEMBRANCA DELL Serie 69                 1
# +TOUCH+TV Motorola Serie 28                   1
# PLASTICO MODERNO TELESP Serie 24              1
# CELULAR COM MP3 CELL LING Serie 33            1
# MEDIA LEMBRANCA VIVALDA Serie 88              1
# MUITA LEMBRANCA ITAUTEC Serie 51              1
# BATE ARNO Serie 67                            1
# VAGA LEMBRANCA DELL Serie 33                  1
# MAIS OU MENOS CONSORTE FUNCA Serie 98         1
# MEDIA LEMBRANCA SISNE Serie 26                1
# UM POUCO DE TUDO BRASNORTH Serie 76           1
# CONDICIONA AR CARRIER Serie 76                1
# ATE 50 LITROS PRADARIA Serie 93               1
# MUITA LEMBRANCA DISMAC Serie 65               1
# IMAGEM ULTRA MONTVELHO Serie 90               1
# MAIS OU MENOS CLARION Serie 90                1
# PLASTICO MODERNO LIXXOR Serie 71              1
# MAIS OU MENOS BRASNORTH Serie 19              1
# PLASTICO MODERNO LIXXOR Serie 47              1
# ATE 50 LITROS BRASTEMP Serie 55               1
# PRETO DO BISAVO TELESP Serie 15               1
# MAIS OU MENOS CLARION Serie 68                1
# BATE BOSCH Serie 37                           1
# VAGA LEMBRANCA MICROTEC Serie 36              1
# PLASTICO DA TELESP VELHUSCO Serie 98          1
# PRETO DO BISAVO LIXXOR Serie 64               1
# CELULAR COM MP3+MP3 JPG Serie 41              1
# MAIS OU MENOS BRASNORTH Serie 58              1
# MOEDORA ARNO Serie 56                         1
# SEM LEMBRANCA BRAS-SUL Serie 54               1
# IMAGEM ULTRA MONTVELHO Serie 98               1
# MUITA LEMBRANCA GRAMPOLA Serie 56             1
# CONDICIONA AR VENTILVA Serie 32               1
# MUITA LEMBRANCA DELL Serie 31                 1
# ALGUMA LEMBRANCA ITAUTEC Serie 02             1
# SEM LEMBRANCA GRAMPOLA Serie 01               1
# MUITA LEMBRANCA CELL LIBERTY Serie 52         1
# IMAGEM ULTRA MONTVELHO Serie 73               1
# MEDIA LEMBRANCA SISNE Serie 43                1
# CELULAR TECLADO PING LING Serie 60            1
# COM RELOGIO CONSORTE FUNCA Serie 11           1
# COM MP3 PLUGS Serie 62                        1
# IMAGEM ULTRA VENDAVAL Serie 94                1
# MOEDORA ARNO Serie 85                         1
# PRETO DO BISAVO TELESP Serie 60               1
# MUITA LEMBRANCA DISMAC Serie 73               1
# CONDICIONA AR CISCO KID Serie 36              1
# COM MP3 PLUGS Serie 89                        1
# BATE BOSCH Serie 81                           1
# MEDIA LEMBRANCA DELL Serie 78                 1
# MEDIA LEMBRANCA MICROLIXO Serie 79            1
# ATE 50 LITROS CONSUL Serie 48                 1
# ALGUMA LEMBRANCA IMPERION Serie 88            1
# CELULAR TECLADO+TOUCH DELETOU Serie 68        1
# COM RELOGIO CONSORTE FUNCA Serie 51           1
# TORRADORA ARNO Serie 68                       1
# MEDIA LEMBRANCA SISNE Serie 57                1
# BATE BOSCH Serie 80                           1
# ATE 30 LITROS PRADARIA Serie 49               1
# MOEDORA BOSCH Serie 53                        1
# MEDIA LEMBRANCA MICROLIXO Serie 71            1
# IMAGEM ULTRA VENDAVAL Serie 42                1
# +TOUCH+TV Motorola Serie 73                   1
# COM RELOGIO BRASNORTH Serie 50                1
# IMAGEM ULTRA VENDAVAL Serie 14                1
# IMAGEM ULTRA MONTVELHO Serie 63               1
# BONZINHO BUSHA DE CANHAO Serie 22             1
# MUITA LEMBRANCA BRAS-SUL Serie 91             1
# PLASTICO MODERNO LIXXOR Serie 29              1
# UM POUCO DE TUDO CLARION Serie 55             1
# TORRADORA LT Serie 54                         1
# PLASTICO MODERNO LIXXOR Serie 53              1
# MUITA LEMBRANCA ITAUTEC Serie 97              1
# MAIS OU MENOS BRASNORTH Serie 87              1
# CONDICIONA AR CISCO KID Serie 72              1
# ATE 20 LITROS PRADARIA Serie 84               1
# ATE 20 LITROS BRASTEMP Serie 17               1
# ATE 50 LITROS CONSUL Serie 10                 1
# CELULAR COM MP3+MP3 CELL LING Serie 84        1
# MEDIA LEMBRANCA VIVALDA Serie 49              1
# CELULAR COM MP3+MP3 JPG Serie 48              1
# PLASTICO DA TELESP VELHUSCO Serie 00          1
# PRETO DO BISAVO VELHUSCO Serie 82             1
# MEDIA LEMBRANCA VIVALDA Serie 39              1
# CELULAR COM MP3 Nokia Serie 43                1
# +TOUCH+TV DELETOU Serie 11                    1
# VENTOSO CARRIER Serie 58                      1
# COM MP3 PRADA Serie 71                        1
# COM RELOGIO CLARION Serie 71                  1
# BATE ARNO Serie 21                            1
# IMAGEM AVANCADA LG Serie 99                   1
# VAGA LEMBRANCA DELL Serie 35                  1
# CELULAR COM MP3+MP3+MP3+TV Nokia Serie 1      1
# COM RELOGIO CONSORTE FUNCA Serie 13           1
# COM MP3 PRADA Serie 13                        1
# CONDICIONA AR CISCO KID Serie 49              1
# BONZINHO PLUGS Serie 99                       1
# +TOUCH+TV Motorola Serie 85                   1
# MUITA LEMBRANCA BRAS-SUL Serie 13             1
# IMAGEM ULTRA LG Serie 28                      1
# SEM LEMBRANCA BRAS-SUL Serie 42               1
# COM MP3 PLUGS Serie 68                        1
# MEDIA LEMBRANCA DISMAC Serie 48               1
# IMAGEM ULTRA MONTVELHO Serie 32               1
# ATE 30 LITROS BRASTEMP Serie 45               1
# VAGA LEMBRANCA MICROTEC Serie 63              1
# PLASTICO DA TELESP VELHUSCO Serie 63          1
# VAGA LEMBRANCA VIVALDA Serie 23               1
# BATE ARNO Serie 40                            1
# ATE 50 LITROS PRADARIA Serie 71               1
# CELULAR COM MP3 Nokia Serie 16                1
# VENTOSO VENTILVA Serie 91                     1
# MEDIA LEMBRANCA MICROLIXO Serie 30            1
# TORRADORA BOSCH Serie 74                      1
# CELULAR COM MP3+MP3 Nokia Serie 69            1
# CELULAR COM MP3+MP3 Nokia Serie 79            1
# ALGUMA LEMBRANCA IMPERION Serie 46            1
# COM RELOGIO BRASNORTH Serie 72                1
# ATE 50 LITROS PRADARIA Serie 75               1
# CELULAR COM MP3+MP3 Nokia Serie 67            1
# ATE 50 LITROS BRASTEMP Serie 09               1
# ATE 20 LITROS PRADARIA Serie 23               1
# +TOUCH+TV PING LING Serie 51                  1
# IMAGEM ULTRA LG Serie 95                      1
# IMAGEM ULTRA VENDAVAL Serie 31                1
# IMAGEM ULTRA LG Serie 78                      1
# PLASTICO DA TELESP LIXXOR Serie 24            1
# CELULAR TECLADO+TOUCH DELETOU Serie 63        1
# SEM LEMBRANCA GRAMPOLA Serie 79               1
# IMAGEM ULTRA VENDAVAL Serie 91                1
# CELULAR COM MP3+MP3 CELL LING Serie 90        1
# CONDICIONA AR CISCO KID Serie 55              1
# IMAGEM AVANCADA LG Serie 70                   1
# MUITA LEMBRANCA DISMAC Serie 64               1
# CELULAR COM MP3+MP3 JPG Serie 43              1
# IMAGEM AVANCADA VENDAVAL Serie 87             1
# MEDIA LEMBRANCA DELL Serie 41                 1
# +TOUCH+TV PING LING Serie 95                  1
# MUITA LEMBRANCA IMPERION Serie 89             1
# MUITA LEMBRANCA ITAUTEC Serie 10              1
# CELULAR COM MP3+MP3 CELL LING Serie 96        1
# ATE 20 LITROS CONSUL Serie 21                 1
# VENTOSO CARRIER Serie 63                      1
# PLASTICO MODERNO LIXXOR Serie 28              1
# COM RELOGIO CONSORTE FUNCA Serie 57           1
# ATE 50 LITROS BRASTEMP Serie 66               1
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 54       1
# BONZINHO PRADA Serie 86                       1
# MAIS OU MENOS CLARION Serie 03                1
# ALGUMA LEMBRANCA MICROTEC Serie 01            1
# MUITA LEMBRANCA GRAMPOLA Serie 73             1
# VENTOSO VENTILVA Serie 71                     1
# CONDICIONA AR VENTILVA Serie 29               1
# MUITA LEMBRANCA CELL LIBERTY Serie 47         1
# PLASTICO MODERNO TELESP Serie 36              1
# IMAGEM AVANCADA MONTVELHO Serie 22            1
# VENTOSO CARRIER Serie 94                      1
# ATE 50 LITROS CONSUL Serie 76                 1
# IMAGEM ULTRA MONTVELHO Serie 70               1
# MEDIA LEMBRANCA SISNE Serie 25                1
# ATE 20 LITROS CONSUL Serie 04                 1
# CELULAR COM MP3+MP3+MP3+TV Nokia Serie 9      1
# IMAGEM ULTRA MONTVELHO Serie 93               1
# IMAGEM ULTRA VENDAVAL Serie 96                1
# CONDICIONA AR CISCO KID Serie 90              1
# COM RELOGIO BRASNORTH Serie 74                1
# MOEDORA LT Serie 96                           1
# MEDIA LEMBRANCA CELL LIBERTY Serie 78         1
# MUITA LEMBRANCA CELL LIBERTY Serie 88         1
# MOEDORA LT Serie 74                           1
# UM POUCO DE TUDO PLUGS Serie 34               1
# CELULAR COM MP3+MP3 Nokia Serie 01            1
# CELULAR COM MP3 JPG Serie 37                  1
# CONDICIONA AR CARRIER Serie 33                1
# IMAGEM AVANCADA VENDAVAL Serie 97             1
# MUITA LEMBRANCA GRAMPOLA Serie 12             1
# ALGUMA LEMBRANCA HP Serie 75                  1
# IMAGEM AVANCADA VENDAVAL Serie 26             1
# MUITA LEMBRANCA ITAUTEC Serie 93              1
# BONZINHO BUSHA DE CANHAO Serie 59             1
# MEDIA LEMBRANCA VIVALDA Serie 29              1
# ATE 50 LITROS CONSUL Serie 55                 1
# MEDIA LEMBRANCA VIVALDA Serie 27              1
# PLASTICO DA TELESP LIXXOR Serie 02            1
# VAGA LEMBRANCA VIVALDA Serie 65               1
# PRETO DO BISAVO TELESP Serie 04               1
# VAGA LEMBRANCA CELL LIBERTY Serie 62          1
# PLASTICO MODERNO LIXXOR Serie 14              1
# CONDICIONA AR CISCO KID Serie 27              1
# RERIGERA CARRIER Serie 27                     1
# VAGA LEMBRANCA DISMAC Serie 36                1
# MEDIA LEMBRANCA SISNE Serie 52                1
# MEDIA LEMBRANCA MICROLIXO Serie 43            1
# BATE LT Serie 61                              1
# CELULAR COM MP3+MP3 JPG Serie 85              1
# MAIS OU MENOS CLARION Serie 02                1
# COM RELOGIO CONSORTE FUNCA Serie 69           1
# TORRADORA LT Serie 70                         1
# PLASTICO MODERNO LIXXOR Serie 89              1
# MUITA LEMBRANCA IMPERION Serie 19             1
# MOEDORA LT Serie 01                           1
# CONDICIONA AR VENTILVA Serie 10               1
# MEDIA LEMBRANCA MICROLIXO Serie 34            1
# CELULAR TECLADO PING LING Serie 19            1
# IMAGEM ULTRA LG Serie 72                      1
# CELULAR TECLADO Motorola Serie 15             1
# +TOUCH+TV PING LING Serie 17                  1
# ALGUMA LEMBRANCA MICROTEC Serie 04            1
# RERIGERA CARRIER Serie 49                     1
# MEDIA LEMBRANCA MICROLIXO Serie 48            1
# +TOUCH+TV PING LING Serie 69                  1
# CELULAR TECLADO DELETOU Serie 84              1
# CONDICIONA AR CISCO KID Serie 60              1
# IMAGEM ULTRA VENDAVAL Serie 99                1
# SEM LEMBRANCA BRAS-SUL Serie 64               1
# ALGUMA LEMBRANCA HP Serie 24                  1
# PLASTICO MODERNO TELESP Serie 54              1
# BATE BOSCH Serie 25                           1
# MUITA LEMBRANCA BRAS-SUL Serie 95             1
# MUITA LEMBRANCA GRAMPOLA Serie 53             1
# ATE 20 LITROS PRADARIA Serie 93               1
# PLASTICO MODERNO LIXXOR Serie 15              1
# ALGUMA LEMBRANCA GRAMPOLA Serie 00            1
# ALGUMA LEMBRANCA GRAMPOLA Serie 49            1
# ALGUMA LEMBRANCA ITAUTEC Serie 56             1
# IMAGEM ULTRA VENDAVAL Serie 92                1
# PLASTICO DA TELESP VELHUSCO Serie 59          1
# MEDIA LEMBRANCA CELL LIBERTY Serie 08         1
# VENTOSO VENTILVA Serie 78                     1
# ATE 20 LITROS CONSUL Serie 06                 1
# RERIGERA CARRIER Serie 59                     1
# MEDIA LEMBRANCA MICROLIXO Serie 59            1
# COM RELOGIO CONSORTE FUNCA Serie 91           1
# PLASTICO DA TELESP VELHUSCO Serie 10          1
# CELULAR TECLADO+TOUCH DELETOU Serie 99        1
# CELULAR COM MP3+MP3+MP3+TV Nokia Serie 7      1
# CELULAR COM MP3 Nokia Serie 51                1
# COM RELOGIO BRASNORTH Serie 68                1
# MUITA LEMBRANCA GRAMPOLA Serie 70             1
# COM RELOGIO CLARION Serie 33                  1
# VAGA LEMBRANCA VIVALDA Serie 43               1
# CELULAR COM MP3+MP3 JPG Serie 99              1
# MUITA LEMBRANCA MICROTEC Serie 92             1
# ATE 50 LITROS CONSUL Serie 92                 1
# ATE 50 LITROS PRADARIA Serie 49               1
# VENTOSO VENTILVA Serie 58                     1
# MAIS OU MENOS BRASNORTH Serie 99              1
# BONZINHO PLUGS Serie 07                       1
# MUITA LEMBRANCA CELL LIBERTY Serie 78         1
# PLASTICO MODERNO LIXXOR Serie 92              1
# ALGUMA LEMBRANCA ITAUTEC Serie 59             1
# +TOUCH+TV Motorola Serie 63                   1
# CELULAR TECLADO+TOUCH PING LING Serie 59      1
# MOEDORA ARNO Serie 58                         1
# +TOUCH+TV DELETOU Serie 99                    1
# MEDIA LEMBRANCA VIVALDA Serie 70              1
# PLASTICO MODERNO LIXXOR Serie 99              1
# MUITA LEMBRANCA DISMAC Serie 49               1
# PLASTICO DA TELESP TELESP Serie 20            1
# MAIS OU MENOS CLARION Serie 56                1
# IMAGEM ULTRA MONTVELHO Serie 85               1
# SEM LEMBRANCA BRAS-SUL Serie 56               1
# MEDIA LEMBRANCA SISNE Serie 50                1
# IMAGEM ULTRA MONTVELHO Serie 92               1
# MEDIA LEMBRANCA MICROLIXO Serie 49            1
# MEDIA LEMBRANCA SISNE Serie 07                1
# BATE BOSCH Serie 47                           1
# MEDIA LEMBRANCA MICROLIXO Serie 42            1
# UM POUCO DE TUDO CLARION Serie 99             1
# IMAGEM NORMAL LG Serie 99                     1
# ATE 20 LITROS BRASTEMP Serie 58               1
# MUITA LEMBRANCA ITAUTEC Serie 27              1
# MUITA LEMBRANCA IMPERION Serie 49             1
# IMAGEM ULTRA MONTVELHO Serie 13               1
# VAGA LEMBRANCA IMPERION Serie 43              1
# MUITA LEMBRANCA GRAMPOLA Serie 92             1
# CONDICIONA AR CISCO KID Serie 34              1
# MAIS OU MENOS CONSORTE FUNCA Serie 01         1
# MEDIA LEMBRANCA MICROLIXO Serie 90            1
# ATE 50 LITROS PRADARIA Serie 30               1
# CONDICIONA AR VENTILVA Serie 33               1
# VENTOSO CARRIER Serie 02                      1
# CELULAR COM MP3+MP3+MP3+TV JPG Serie 69       1
# VENTOSO CISCO KID Serie 93                    1
# RERIGERA CARRIER Serie 18                     1
# MUITA LEMBRANCA DISMAC Serie 90               1
# BATE BOSCH Serie 83                           1
# PLASTICO MODERNO TELESP Serie 12              1
# MUITA LEMBRANCA GRAMPOLA Serie 31             1
# BONZINHO PRADA Serie 48                       1
# MEDIA LEMBRANCA MICROLIXO Serie 89            1
# ATE 30 LITROS PRADARIA Serie 44               1
# PLASTICO DA TELESP VELHUSCO Serie 44          1
# IMAGEM ULTRA MONTVELHO Serie 17               1
# VAGA LEMBRANCA SISNE Serie 61                 1
# ATE 20 LITROS PRADARIA Serie 54               1
# MEDIA LEMBRANCA MICROLIXO Serie 88            1
# MUITA LEMBRANCA DISMAC Serie 51               1
# IMAGEM ULTRA VENDAVAL Serie 22                1
# VAGA LEMBRANCA SISNE Serie 14                 1
# COM RELOGIO CLARION Serie 15                  1
# BATE BOSCH Serie 98                           1
# BONZINHO PLUGS Serie 48                       1
# TORRADORA ARNO Serie 83                       1
# IMAGEM ULTRA MONTVELHO Serie 20               1
# MOEDORA LT Serie 57                           1
# VAGA LEMBRANCA CELL LIBERTY Serie 35          1
# MEDIA LEMBRANCA SISNE Serie 38                1
# ALGUMA LEMBRANCA HP Serie 36                  1
# CELULAR TECLADO Motorola Serie 12             1
# PLASTICO MODERNO LIXXOR Serie 10              1
# MEDIA LEMBRANCA VIVALDA Serie 91              1
# BONZINHO PLUGS Serie 85                       1
# PLASTICO DA TELESP TELESP Serie 03            1
# CELULAR TECLADO DELETOU Serie 20              1
# MAIS OU MENOS BRASNORTH Serie 85              1
# IMAGEM ULTRA MONTVELHO Serie 24               1
# ATE 30 LITROS CONSUL Serie 24                 1
# MEDIA LEMBRANCA SISNE Serie 30                1
# +TOUCH+TV Motorola Serie 94                   1
# ATE 30 LITROS PRADARIA Serie 85               1
# ATE 30 LITROS CONSUL Serie 49                 1
# CELULAR TECLADO+TOUCH Motorola Serie 42       1
# COM RELOGIO BRASNORTH Serie 30                1
# VAGA LEMBRANCA DISMAC Serie 41                1
# CELULAR TECLADO+TOUCH PING LING Serie 98      1
# MUITA LEMBRANCA MICROTEC Serie 37             1
# VAGA LEMBRANCA MICROLIXO Serie 99             1
# PRETO DO BISAVO VELHUSCO Serie 21             1
# CONDICIONA AR CARRIER Serie 45                1
# MUITA LEMBRANCA DISMAC Serie 91               1
# BONZINHO PRADA Serie 05                       1
# MAIS OU MENOS BRASNORTH Serie 80              1
# BONZINHO BUSHA DE CANHAO Serie 08             1
# COM RELOGIO CONSORTE FUNCA Serie 24           1
# +TOUCH+TV DELETOU Serie 90                    1
# SEM LEMBRANCA ITAUTEC Serie 40                1
# CELULAR COM MP3 Nokia Serie 32                1
# CELULAR TECLADO PING LING Serie 94            1
# TORRADORA LT Serie 91                         1
# SEM LEMBRANCA BRAS-SUL Serie 95               1
# PLASTICO MODERNO TELESP Serie 07              1
# UM POUCO DE TUDO BRASNORTH Serie 03           1
# COM MP3 BUSHA DE CANHAO Serie 52              1
# ATE 20 LITROS BRASTEMP Serie 00               1
# CELULAR TECLADO Motorola Serie 95             1
# MUITA LEMBRANCA GRAMPOLA Serie 28             1
# PLASTICO MODERNO LIXXOR Serie 23              1
# CELULAR TECLADO+TOUCH PING LING Serie 76      1
# MOEDORA ARNO Serie 54                         1
# +TOUCH+TV DELETOU Serie 38                    1
# COM MP3 PLUGS Serie 99                        1
# CONDICIONA AR VENTILVA Serie 93               1
# ATE 30 LITROS PRADARIA Serie 83               1
# UM POUCO DE TUDO CLARION Serie 77             1
# ALGUMA LEMBRANCA BRAS-SUL Serie 62            1
# COM RELOGIO CONSORTE FUNCA Serie 50           1
# TORRADORA ARNO Serie 46                       1
# MUITA LEMBRANCA IMPERION Serie 56             1
# BONZINHO PLUGS Serie 63                       1
# ALGUMA LEMBRANCA ITAUTEC Serie 41             1
# ALGUMA LEMBRANCA IMPERION Serie 58            1
# PLASTICO MODERNO TELESP Serie 44              1
# IMAGEM NORMAL VENDAVAL Serie 73               1
# ATE 20 LITROS BRASTEMP Serie 97               1
# COM RELOGIO CLARION Serie 32                  1
# VAGA LEMBRANCA IMPERION Serie 55              1
# CELULAR TECLADO PING LING Serie 97            1
# MUITA LEMBRANCA GRAMPOLA Serie 80             1
# COM MP3 PLUGS Serie 14                        1
# ATE 30 LITROS PRADARIA Serie 80               1
# CELULAR TECLADO+TOUCH Motorola Serie 06       1
# SEM LEMBRANCA GRAMPOLA Serie 57               1
# PRETO DO BISAVO VELHUSCO Serie 80             1
# ALGUMA LEMBRANCA MICROTEC Serie 67            1
# MUITA LEMBRANCA BRAS-SUL Serie 44             1
# BONZINHO PRADA Serie 09                       1
# TORRADORA BOSCH Serie 32                      1
# +TOUCH+TV PING LING Serie 12                  1
# IMAGEM ULTRA LG Serie 53                      1
# MAIS OU MENOS CONSORTE FUNCA Serie 03         1
# MUITA LEMBRANCA GRAMPOLA Serie 72             1
# TORRADORA LT Serie 58                         1
# MUITA LEMBRANCA IMPERION Serie 70             1
# +TOUCH+TV PING LING Serie 68                  1
# MEDIA LEMBRANCA DELL Serie 40                 1
# IMAGEM NORMAL VENDAVAL Serie 37               1
# UM POUCO DE TUDO PRADA Serie 99               1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2433 entries, 0 to 4578
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cd_produto                  2433 non-null   int64
#  1   qtde                        2433 non-null   int64
#  2   nota                        2433 non-null   int64
#  3   preco_liq                   2433 non-null   float64
#  4   preco_ipi                   2433 non-null   float64
#  5   preco_icms                  2433 non-null   float64
#  6   p_ipi                       2433 non-null   int64
#  7   p_icm                       2433 non-null   int64
#  8   nm_produto                  2433 non-null   object
#  9   cd_cliente                  2433 non-null   float64
#  10  nm_cliente                  2433 non-null   object
#  11  cidade                      2433 non-null   object
#  12  uf                          2433 non-null   object
#  13  cd_vendedor                 2433 non-null   int64
#  14  nm_vendedor                 2433 non-null   object
#  15  cd_familia                  2433 non-null   int64
#  16  nm_familia                  2433 non-null   object
#  17  cd_grupo                    2433 non-null   int64
#  18  nm_grupo                    2433 non-null   object
#  19  cd_marca                    2433 non-null   int64
#  20  nm_marca                    2433 non-null   object
#  21  data_pedido                 2433 non-null   datetime64[ns]
#  22  data_nota                   2433 non-null   object
#  23  cd_operacao                 2433 non-null   float64
#  24  nm_operacao                 2433 non-null   object
#  25  cd_sub_grupo                2433 non-null   int64
#  26  nm_sub_grupo                2433 non-null   object
#  27  cd_linha                    2433 non-null   int64
#  28  nm_linha                    2433 non-null   object
#  29  valor                       2433 non-null   float64
#  30  lucro                       2433 non-null   float64
#  31  mes_ano                     2433 non-null   period[M]
#  32  dia_da_semana               2433 non-null   object
#  33  categoria_produto           2433 non-null   object
#  34  data_primeira_compra        2433 non-null   datetime64[ns]
#  35  data_ultima_compra          2433 non-null   datetime64[ns]
#  36  dias_desde_primeira_compra  2433 non-null   int64
#  37  dias_desde_ultima_compra    2433 non-null   int64
# dtypes: datetime64[ns](3), float64(7), int64(13), object(14), period[M](1)
# memory usage: 741.3+ KB
